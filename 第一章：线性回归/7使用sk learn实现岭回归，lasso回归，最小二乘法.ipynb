# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# 加载数据

# %%
def load_data():
    data = np.loadtxt('data.txt',delimiter=' ')
    n = data.shape[1]-1
    X = data[:,0:n]
    y = data[:,-1].reshape(-1,1)
    return X,y
X,y = load_data()
X,y
# Out:
# (array([[0.1],
#         [0.5],
#         [0.9],
#         [1.3],
#         [1.7],
#         [2. ],
#         [2.4],
#         [2.8],
#         [3.2],
#         [3.6],
#         [4. ],
#         [4.4],
#         [4.8],
#         [5.2],
#         [5.6],
#         [6. ],
#         [6.4],
#         [6.8],
#         [7.2],
#         [7.6],
#         [8. ]]),
#  array([[ 5.3],
#         [ 6.2],
#         [ 6.8],
#         [ 7.5],
#         [ 8.1],
#         [ 9. ],
#         [ 9.6],
#         [10.1],
#         [10.7],
#         [11.3],
#         [12. ],
#         [12.6],
#         [13.2],
#         [13.8],
#         [14.4],
#         [15. ],
#         [15.6],
#         [16.2],
#         [16.8],
#         [17.4],
#         [18. ]]))

# %% [markdown]
# 1.最小二乘法

# %%
model1 = linear_model.LinearRegression()

# %%
model1.fit(X,y)#使用训练模型
# Out:
# LinearRegression()

# %%
print(model1.coef_)#输出系数
print(model1.intercept_)#输出截距

plt.scatter(X[:,0],y)
plt.plot(X[:,0],model1.predict(X),color='red')
# Out:
# [[1.57922485]]
# [5.5312143]

# %% [markdown]
# 2.Ridge回归

# %%
model2 = linear_model.Ridge(alpha=0.5)
model2.fit(X,y)
# Out:
# Ridge(alpha=0.5)

# %%
print(model2.coef_)
print(model2.intercept_)
plt.scatter(X[:,0],y)
plt.plot(X[:,0],model2.predict(X),color='red')
# Out:
# [1.57267412]
# [5.55757318]

# %% [markdown]
# 3.LASSO回归

# %%
model3 = linear_model.Lasso(alpha=0.5)
model3.fit(X,y)
print(model3.coef_)
print(model3.intercept_)
plt.scatter(X[:,0],y)
plt.plot(X[:,0],model3.predict(X),color='red')
# Out:
# [1.49175262]
# [5.88318589]

# %% [markdown]
# 4.ElactisNet
# 弹性网模型
# 结合Ridge和Lasso（L1与L2正则化）

# %%
model4 = linear_model.ElasticNet(alpha=0.5)
model4.fit(X,y)
print(model4.coef_)
print(model4.intercept_)
plt.scatter(X[:,0],y)
plt.plot(X[:,0],model4.predict(X),color='red')
# Out:
# [1.4711465]
# [5.96610099]
