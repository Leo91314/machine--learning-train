# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 求y=x^2+2x+5的最小值

# %%
x=np.linspace(-6,4,100)
y=x**2+2*x+5
plt.plot(x,y)

# %% [markdown]
# 初始化横坐标与学习率（迭代次数）

# %%
x=4
lr=0.1
iteraterNum = 100000

# %% [markdown]
# 迭代求thera

# %%
for i in range(iteraterNum):
    gradient = 2*x+2
    x = x-lr*gradient

# %%
x
# Out:
# -0.9999999999999998
