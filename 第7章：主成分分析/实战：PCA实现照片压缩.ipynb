# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import matplotlib.image as mpimg
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
img = mpimg.imread('data/jjq.jpg')

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (800, 600, 3)

# %%
X = img.reshape(1200, 1200)

# %%
X = StandardScaler().fit_transform(X)

# %%
model = PCA(n_components=100)
X_new = model.fit_transform(X)

# %%
X_new.shape
# Out:
# (1200, 100)

# %%
print(sum(model.explained_variance_ratio_))
# Out:
# 0.9960070604888629

# %%
X_rec = model.inverse_transform(X_new)
X_rec = X_rec.reshape(800,600,3)
plt.imshow(X_rec)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.7835954166621266..2.567296575614347].
